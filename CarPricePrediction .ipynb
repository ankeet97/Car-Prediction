# %% [markdown]
# # CarPricePrediction

# %%
# !pip3 install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\hp\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)

# %%
# !pip install BeautifulSoup4
# Out:
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\hp\anaconda3\lib\site-packages)
# Requirement already satisfied: BeautifulSoup4 in c:\users\hp\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from BeautifulSoup4) (2.3.1)

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import time
import selenium
import requests
import re
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import warnings
warnings.filterwarnings("ignore")

# %%
#connect to the webdriver
driver = webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = "https://www.cardekho.com/used-cars+in+bangalore"
driver.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

# %%
time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df1=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df1
# Out:
#                         Brand       Price                          Model  \
# 0             2016 Honda City   6.50 Lakh                       i VTEC V
# 1           2017 Renault KWID   3.90 Lakh  1.0 RXT Optional AT 2016-2019
# 2        2014 Maruti Alto K10   2.76 Lakh                  2010-2014 VXI
# 3           2021 Nissan Kicks  15.10 Lakh           1.3 Turbo XV Pre CVT
# 4   2021 Toyota Urban cruiser  10.20 Lakh                           High
# ..                        ...         ...                            ...
# 75        2014 Renault Duster   6.25 Lakh           85PS Diesel RxL Plus
# 76           2018 Ford Aspire   5.75 Lakh                  Titanium BSIV
# 77         2021 Hyundai Creta  19.99 Lakh          SX Opt Turbo Dualtone
# 78                2020 BMW X7     1.18 Cr                     xDrive 40i
# 79                2021 BMW X1  43.75 Lakh               sDrive20i SportX
#
#     KMS_driven    Fuel    Variant
# 0   88,036 kms  Petrol     Manual
# 1   45,567 kms  Petrol  Automatic
# 2   80,293 kms  Petrol     Manual
# 3    6,660 kms  Petrol  Automatic
# 4    5,467 kms  Petrol     Manual
# ..         ...     ...        ...
# 75  60,000 kms  Diesel     Manual
# 76  34,500 kms  Petrol     Manual
# 77   8,300 kms  Petrol  Automatic
# 78  14,000 kms  Petrol  Automatic
# 79   8,000 kms  Petrol  Automatic
#
# [80 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# ## Ahmedabad

# %%
#connect to the webdriver
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+ahmedabad"
driver.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
manuf_year=[]
Driven_KM=[]
fuel=[]
location=[]
No_owners=[]
price=[]

# %%
time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df2=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df2
# Out:
#                                Brand       Price                 Model  \
# 0                2018 Hyundai Santro   5.20 Lakh       Sportz AMT BSIV
# 1                  2020 Renault KWID   4.52 Lakh      1.0 RXT Opt BSIV
# 2                    2016 Honda City   7.33 Lakh              i VTEC V
# 3                2018 Renault Duster   7.21 Lakh        Petrol RXS CVT
# 4                   2016 Maruti Ciaz   6.12 Lakh              VXi Plus
# ..                               ...         ...                   ...
# 75  2021 BMW 3 Series Gran Limousine  53.75 Lakh  320Ld Iconic Edition
# 76                2017 Porsche Macan  58.00 Lakh                    R4
# 77                       2020 BMW X7     1.18 Cr            xDrive 40i
# 78        2016 Mercedes-Benz S-Class     1.61 Cr         AMG S63 Coupe
# 79                2020 Porsche Macan  79.50 Lakh     3.0 Twin Turbo V6
#
#     KMS_driven    Fuel    Variant
# 0   16,929 kms  Petrol  Automatic
# 1    4,463 kms  Petrol     Manual
# 2   25,542 kms  Petrol     Manual
# 3   33,139 kms  Petrol  Automatic
# 4   36,534 kms  Petrol     Manual
# ..         ...     ...        ...
# 75  12,000 kms  Diesel  Automatic
# 76  25,000 kms  Petrol  Automatic
# 77  14,000 kms  Petrol  Automatic
# 78  16,000 kms  Petrol  Automatic
# 79  16,000 kms  Petrol  Automatic
#
# [80 rows x 6 columns]

# %%
data = [df1, df2]
  
result = pd.concat(data)
display(result)
# Out:
#                                Brand       Price  \
# 0                    2016 Honda City   6.50 Lakh
# 1                  2017 Renault KWID   3.90 Lakh
# 2               2014 Maruti Alto K10   2.76 Lakh
# 3                  2021 Nissan Kicks  15.10 Lakh
# 4          2021 Toyota Urban cruiser  10.20 Lakh
# ..                               ...         ...
# 75  2021 BMW 3 Series Gran Limousine  53.75 Lakh
# 76                2017 Porsche Macan  58.00 Lakh
# 77                       2020 BMW X7     1.18 Cr
# 78        2016 Mercedes-Benz S-Class     1.61 Cr
# 79                2020 Porsche Macan  79.50 Lakh
#
#                             Model  KMS_driven    Fuel    Variant
# 0                        i VTEC V  88,036 kms  Petrol     Manual
# 1   1.0 RXT Optional AT 2016-2019  45,567 kms  Petrol  Automatic
# 2                   2010-2014 VXI  80,293 kms  Petrol     Manual
# 3            1.3 Turbo XV Pre CVT   6,660 kms  Petrol  Automatic
# 4                            High   5,467 kms  Petrol     Manual
# ..                            ...         ...     ...        ...
# 75           320Ld Iconic Edition  12,000 kms  Diesel  Automatic
# 76                             R4  25,000 kms  Petrol  Automatic
# 77                     xDrive 40i  14,000 kms  Petrol  Automatic
# 78                  AMG S63 Coupe  16,000 kms  Petrol  Automatic
# 79              3.0 Twin Turbo V6  16,000 kms  Petrol  Automatic
#
# [160 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# ## Mumbai

# %%
#connect to the webdriver
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+mumbai"
driver.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

# %%
time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df3=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df3
# Out:
#                       Brand       Price                        Model  \
# 0   2017 Maruti Swift Dzire   5.88 Lakh                          VXI
# 1         2017 Maruti Ignis   4.91 Lakh               1.2 Alpha BSIV
# 2        2016 Hyundai Creta   9.87 Lakh                  1.6 CRDi SX
# 3        2014 Hyundai Verna   5.36 Lakh                     1.4 VTVT
# 4          2017 Maruti Ciaz   6.04 Lakh                          ZXi
# ..                      ...         ...                          ...
# 75   2015 Hyundai Grand i10   4.45 Lakh                         Asta
# 76      2017 Hyundai Tucson  17.76 Lakh  2.0 Dual VTVT 2WD AT GL Opt
# 77       2018 Hyundai Creta  12.80 Lakh             1.6 SX Automatic
# 78    2014 Volkswagen Vento   4.96 Lakh       1.2 TSI Comfortline AT
# 79    2017 Volkswagen Vento   8.35 Lakh     1.2 TSI Highline Plus AT
#
#     KMS_driven    Fuel    Variant
# 0   32,754 kms  Petrol     Manual
# 1   60,393 kms  Petrol     Manual
# 2   89,715 kms  Diesel     Manual
# 3   17,519 kms  Petrol     Manual
# 4   71,376 kms  Petrol     Manual
# ..         ...     ...        ...
# 75  26,000 kms  Petrol     Manual
# 76  19,000 kms  Petrol  Automatic
# 77  50,000 kms  Petrol  Automatic
# 78  52,000 kms  Petrol  Automatic
# 79  18,500 kms  Petrol  Automatic
#
# [80 rows x 6 columns]

# %%
data1 = [result, df3]
  
r1 = pd.concat(data1)
display(r1)
# Out:
#                         Brand       Price                          Model  \
# 0             2016 Honda City   6.50 Lakh                       i VTEC V
# 1           2017 Renault KWID   3.90 Lakh  1.0 RXT Optional AT 2016-2019
# 2        2014 Maruti Alto K10   2.76 Lakh                  2010-2014 VXI
# 3           2021 Nissan Kicks  15.10 Lakh           1.3 Turbo XV Pre CVT
# 4   2021 Toyota Urban cruiser  10.20 Lakh                           High
# ..                        ...         ...                            ...
# 75     2015 Hyundai Grand i10   4.45 Lakh                           Asta
# 76        2017 Hyundai Tucson  17.76 Lakh    2.0 Dual VTVT 2WD AT GL Opt
# 77         2018 Hyundai Creta  12.80 Lakh               1.6 SX Automatic
# 78      2014 Volkswagen Vento   4.96 Lakh         1.2 TSI Comfortline AT
# 79      2017 Volkswagen Vento   8.35 Lakh       1.2 TSI Highline Plus AT
#
#     KMS_driven    Fuel    Variant
# 0   88,036 kms  Petrol     Manual
# 1   45,567 kms  Petrol  Automatic
# 2   80,293 kms  Petrol     Manual
# 3    6,660 kms  Petrol  Automatic
# 4    5,467 kms  Petrol     Manual
# ..         ...     ...        ...
# 75  26,000 kms  Petrol     Manual
# 76  19,000 kms  Petrol  Automatic
# 77  50,000 kms  Petrol  Automatic
# 78  52,000 kms  Petrol  Automatic
# 79  18,500 kms  Petrol  Automatic
#
# [240 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# ## Jaipur

# %%
#connect to the webdriver
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+jaipur"
driver.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

# %%
time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver.find_elements(By.XPATH,("//div[@class='gsc_col-xs-7  carsName']/a"))
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements(By.XPATH,("//span[@class='amnt ']"))
    for i in prices:
        price.append(i.text)
        
    models=driver.find_elements(By.XPATH,("//div[@class='car_variant']"))
    for i in models:
        model.append(i.text)  
        
    kms=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df4=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df4
# Out:
#                                Brand       Price                 Model  \
# 0                    2018 Honda City   9.10 Lakh         i-VTEC CVT ZX
# 1                    2017 Honda City   9.45 Lakh         i-VTEC CVT ZX
# 2            2017 Maruti Swift Dzire   6.65 Lakh               AMT ZDI
# 3                    2020 Honda City  13.40 Lakh                ZX CVT
# 4                    2020 Honda City  11.90 Lakh                ZX CVT
# ..                               ...         ...                   ...
# 75                       2021 BMW X1  43.75 Lakh      sDrive20i SportX
# 76        2016 Mercedes-Benz S-Class     1.61 Cr         AMG S63 Coupe
# 77  2021 BMW 3 Series Gran Limousine  53.75 Lakh  320Ld Iconic Edition
# 78            2021 Mercedes-Benz GLS     1.33 Cr           400d 4MATIC
# 79                2020 Porsche Macan  79.50 Lakh     3.0 Twin Turbo V6
#
#       KMS_driven    Fuel    Variant
# 0     26,186 kms  Petrol  Automatic
# 1     27,787 kms  Petrol  Automatic
# 2   1,05,894 kms  Diesel  Automatic
# 3     36,410 kms  Petrol  Automatic
# 4     55,617 kms  Petrol  Automatic
# ..           ...     ...        ...
# 75     8,000 kms  Petrol  Automatic
# 76    16,000 kms  Petrol  Automatic
# 77    12,000 kms  Diesel  Automatic
# 78     4,000 kms  Diesel  Automatic
# 79    16,000 kms  Petrol  Automatic
#
# [80 rows x 6 columns]

# %%
data2 = [r1,df4]
r2 = pd.concat(data2)
display(r2)
# Out:
#                                Brand       Price  \
# 0                    2016 Honda City   6.50 Lakh
# 1                  2017 Renault KWID   3.90 Lakh
# 2               2014 Maruti Alto K10   2.76 Lakh
# 3                  2021 Nissan Kicks  15.10 Lakh
# 4          2021 Toyota Urban cruiser  10.20 Lakh
# ..                               ...         ...
# 75                       2021 BMW X1  43.75 Lakh
# 76        2016 Mercedes-Benz S-Class     1.61 Cr
# 77  2021 BMW 3 Series Gran Limousine  53.75 Lakh
# 78            2021 Mercedes-Benz GLS     1.33 Cr
# 79                2020 Porsche Macan  79.50 Lakh
#
#                             Model  KMS_driven    Fuel    Variant
# 0                        i VTEC V  88,036 kms  Petrol     Manual
# 1   1.0 RXT Optional AT 2016-2019  45,567 kms  Petrol  Automatic
# 2                   2010-2014 VXI  80,293 kms  Petrol     Manual
# 3            1.3 Turbo XV Pre CVT   6,660 kms  Petrol  Automatic
# 4                            High   5,467 kms  Petrol     Manual
# ..                            ...         ...     ...        ...
# 75               sDrive20i SportX   8,000 kms  Petrol  Automatic
# 76                  AMG S63 Coupe  16,000 kms  Petrol  Automatic
# 77           320Ld Iconic Edition  12,000 kms  Diesel  Automatic
# 78                    400d 4MATIC   4,000 kms  Diesel  Automatic
# 79              3.0 Twin Turbo V6  16,000 kms  Petrol  Automatic
#
# [320 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# # Gurgoan

# %%
#connect to the webdriver
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+gurgaon"
driver.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

# %%
time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df5=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df5
# Out:
#                                Brand       Price                 Model  \
# 0               2017 Maruti Alto 800   2.81 Lakh                   LXI
# 1                 2018 Mahindra Thar   8.05 Lakh                  CRDe
# 2                 2016 Hyundai Creta   8.12 Lakh      1.6 VTVT SX Plus
# 3               2019 Mahindra XUV500  15.80 Lakh           W11 AT BSIV
# 4            2015 Maruti Swift Dzire   3.99 Lakh                   LDI
# ..                               ...         ...                   ...
# 75                       2021 BMW X1  43.75 Lakh      sDrive20i SportX
# 76  2021 BMW 3 Series Gran Limousine  53.75 Lakh  320Ld Iconic Edition
# 77               2018 Ford Endeavour  28.75 Lakh   3.2 Titanium AT 4X4
# 78        2016 Mercedes-Benz S-Class     1.61 Cr         AMG S63 Coupe
# 79                       2020 BMW X7     1.18 Cr            xDrive 40i
#
#     KMS_driven    Fuel    Variant
# 0   84,088 kms  Petrol     Manual
# 1   33,637 kms  Diesel     Manual
# 2   74,978 kms  Petrol     Manual
# 3   60,150 kms  Diesel  Automatic
# 4   67,090 kms  Diesel     Manual
# ..         ...     ...        ...
# 75   8,000 kms  Petrol  Automatic
# 76  12,000 kms  Diesel  Automatic
# 77  40,000 kms  Diesel  Automatic
# 78  16,000 kms  Petrol  Automatic
# 79  14,000 kms  Petrol  Automatic
#
# [80 rows x 6 columns]

# %%
data3= [r2, df5]
  
r3 = pd.concat(data3)
driver.close()
display(r3)
# Out:
#                                Brand       Price  \
# 0                    2016 Honda City   6.50 Lakh
# 1                  2017 Renault KWID   3.90 Lakh
# 2               2014 Maruti Alto K10   2.76 Lakh
# 3                  2021 Nissan Kicks  15.10 Lakh
# 4          2021 Toyota Urban cruiser  10.20 Lakh
# ..                               ...         ...
# 75                       2021 BMW X1  43.75 Lakh
# 76  2021 BMW 3 Series Gran Limousine  53.75 Lakh
# 77               2018 Ford Endeavour  28.75 Lakh
# 78        2016 Mercedes-Benz S-Class     1.61 Cr
# 79                       2020 BMW X7     1.18 Cr
#
#                             Model  KMS_driven    Fuel    Variant
# 0                        i VTEC V  88,036 kms  Petrol     Manual
# 1   1.0 RXT Optional AT 2016-2019  45,567 kms  Petrol  Automatic
# 2                   2010-2014 VXI  80,293 kms  Petrol     Manual
# 3            1.3 Turbo XV Pre CVT   6,660 kms  Petrol  Automatic
# 4                            High   5,467 kms  Petrol     Manual
# ..                            ...         ...     ...        ...
# 75               sDrive20i SportX   8,000 kms  Petrol  Automatic
# 76           320Ld Iconic Edition  12,000 kms  Diesel  Automatic
# 77            3.2 Titanium AT 4X4  40,000 kms  Diesel  Automatic
# 78                  AMG S63 Coupe  16,000 kms  Petrol  Automatic
# 79                     xDrive 40i  14,000 kms  Petrol  Automatic
#
# [400 rows x 6 columns]

# %% [markdown]
# # DELHI NCR

# %%
#connect to the webdriver
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.cardekho.com/used-cars+in+delhi-ncr"
driver.get(url)
time.sleep(6)

# %%
brand=[]
model=[]
variant=[]
Driven_KM=[]
fuel=[]
price=[]

# %%
time.sleep(3)

start=0
end=4
for page in range(start,end):
    
    brands=driver.find_elements(By.XPATH,"//div[@class='gsc_col-xs-7  carsName']/a")
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements(By.XPATH,"//span[@class='amnt ']")
    for i in prices:
        price.append(i.text)
        
    models=driver.find_elements(By.XPATH,"//div[@class='car_variant']")
    for i in models:
        model.append(i.text)  
        
    kms=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[1]"))
    for i in kms:
        Driven_KM.append(i.text)
        
    fuels=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[2]"))
    for i in fuels:
        fuel.append(i.text)
        
    variants=driver.find_elements(By.XPATH,("//div[@class='truncate dotlist-2']/div[3]"))
    for i in variants:
        variant.append(i.text)

# %%
df6=pd.DataFrame({
'Brand':brand[:],                 
'Price':price[:],
'Model':model[:],
'KMS_driven':Driven_KM[:],
'Fuel':fuel[:],
'Variant':variant[:]})
df6
# Out:
#                                Brand       Price                 Model  \
# 0               2017 Maruti Alto 800   2.81 Lakh                   LXI
# 1                 2018 Mahindra Thar   8.05 Lakh                  CRDe
# 2                 2016 Hyundai Creta   8.12 Lakh      1.6 VTVT SX Plus
# 3               2019 Mahindra XUV500  15.80 Lakh           W11 AT BSIV
# 4            2015 Maruti Swift Dzire   3.99 Lakh                   LDI
# ..                               ...         ...                   ...
# 75                       2021 BMW X1  43.75 Lakh      sDrive20i SportX
# 76        2016 Mercedes-Benz S-Class     1.61 Cr         AMG S63 Coupe
# 77  2021 BMW 3 Series Gran Limousine  53.75 Lakh  320Ld Iconic Edition
# 78                2020 Porsche Macan  79.50 Lakh     3.0 Twin Turbo V6
# 79                       2020 BMW X7     1.18 Cr            xDrive 40i
#
#     KMS_driven    Fuel    Variant
# 0   84,088 kms  Petrol     Manual
# 1   33,637 kms  Diesel     Manual
# 2   74,978 kms  Petrol     Manual
# 3   60,150 kms  Diesel  Automatic
# 4   67,090 kms  Diesel     Manual
# ..         ...     ...        ...
# 75   8,000 kms  Petrol  Automatic
# 76  16,000 kms  Petrol  Automatic
# 77  12,000 kms  Diesel  Automatic
# 78  16,000 kms  Petrol  Automatic
# 79  14,000 kms  Petrol  Automatic
#
# [80 rows x 6 columns]

# %%
data4 = [r3, df6]
  
r4 = pd.concat(data4)
display(r4)
# Out:
#                                Brand       Price  \
# 0                    2016 Honda City   6.50 Lakh
# 1                  2017 Renault KWID   3.90 Lakh
# 2               2014 Maruti Alto K10   2.76 Lakh
# 3                  2021 Nissan Kicks  15.10 Lakh
# 4          2021 Toyota Urban cruiser  10.20 Lakh
# ..                               ...         ...
# 75                       2021 BMW X1  43.75 Lakh
# 76        2016 Mercedes-Benz S-Class     1.61 Cr
# 77  2021 BMW 3 Series Gran Limousine  53.75 Lakh
# 78                2020 Porsche Macan  79.50 Lakh
# 79                       2020 BMW X7     1.18 Cr
#
#                             Model  KMS_driven    Fuel    Variant
# 0                        i VTEC V  88,036 kms  Petrol     Manual
# 1   1.0 RXT Optional AT 2016-2019  45,567 kms  Petrol  Automatic
# 2                   2010-2014 VXI  80,293 kms  Petrol     Manual
# 3            1.3 Turbo XV Pre CVT   6,660 kms  Petrol  Automatic
# 4                            High   5,467 kms  Petrol     Manual
# ..                            ...         ...     ...        ...
# 75               sDrive20i SportX   8,000 kms  Petrol  Automatic
# 76                  AMG S63 Coupe  16,000 kms  Petrol  Automatic
# 77           320Ld Iconic Edition  12,000 kms  Diesel  Automatic
# 78              3.0 Twin Turbo V6  16,000 kms  Petrol  Automatic
# 79                     xDrive 40i  14,000 kms  Petrol  Automatic
#
# [480 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# Saving the data

# %%
r4.to_excel("Used_Cars_Data.xlsx")

# %%
r4.to_csv("Used_Cars_Data.csv")
